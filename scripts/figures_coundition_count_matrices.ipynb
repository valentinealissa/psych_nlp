# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# psych_encounters_insurance_counts = pd.read_csv('../data/clean_psych_patient_encounter_conditions.csv')
# psych_encounters = pd.read_csv('../data/psych_encounters.csv')
# patient_info = pd.read_csv("../data/clean_psych_patient.csv")
# condition_ratios_broadICD = pd.read_csv("../data/psych_patients_condition_ratios_broadICD.csv")

CCSR = pd.read_csv("../data/all_encounters_condition_count_matrix_CCSR.csv")
# CCSR = pd.read_csv("../data/psych_encounters_condition_count_matrix_CCSR.csv")
# ICD = pd.read_csv("../data/all_encounters_condition_count_matrix_ICD.csv")

# %%
ccsr = pd.read_csv("/Users/valena17/DataGripProjects/msdw2/psych_diagnoses/ccsr_fcodes.csv")
ccsr = ccsr.applymap(lambda x: x.replace("'", ""))
ccsr = ccsr[['ICD-10-CM CODE', 'Default CCSR CATEGORY DESCRIPTION OP']]
ccsr_mapping = ccsr.set_index('ICD-10-CM CODE').T.to_dict('list')
ccsr_mapping['F0150']
# Out:
# ['Neurocognitive disorders']

# %%
map = pd.read_csv("/Users/valena17/DataGripProjects/msdw2/psych_diagnoses/snomed_icd_map.csv")
map = map[['referencedComponentName', 'mapTarget', 'mapTargetName']]
mapping_d = map.set_index('referencedComponentName').T.to_dict('list')
mapping_d['Failure of orgasm']
# Out:
# /var/folders/xm/m4dy5bvs1fn7fb9wxjhsg4dc0000gn/T/ipykernel_28856/2861663421.py:3: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   mapping_d = map.set_index('referencedComponentName').T.to_dict('list')
# ['F52.32', 'Male orgasmic disorder']

# %%
h = pd.read_csv("/Users/valena17/DataGripProjects/msdw2/psych_diagnoses/icd_fcode_hierarchy.csv")
h = h[['hierarchy', 'top_h']].drop_duplicates()
mapping_h = h.set_index('hierarchy').T.to_dict('list')
mapping_h['F01.5']
# Out:
# ['F01']

# %%
male = CCSR.loc[CCSR.merged_gender.isin(['Male'])]
male_black = male.loc[male.merged_race_ethnicity_v2.isin(['Black or African American'])]
male_black = male_black.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp=sns.heatmap(male_black, annot=False,cmap="PuBu_r", yticklabels=False)
plt.savefig('../figures/male_black_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
female = CCSR.loc[CCSR.merged_gender.isin(['Female'])]
female_black = female.loc[female.merged_race_ethnicity_v2.isin(['Black or African American'])]
female_black = female_black.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp=sns.heatmap(female_black, annot=False,cmap="PuBu_r", yticklabels=False)
plt.savefig('../figures/female_black_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
male = CCSR.loc[CCSR.merged_gender.isin(['Male'])]
male_white = male.loc[male.merged_race_ethnicity_v2.isin(['White'])]
male_white = male_white.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp=sns.heatmap(male_white, annot=False,cmap="PuBu_r", yticklabels=False)
plt.savefig('../figures/male_white_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
female = CCSR.loc[CCSR.merged_gender.isin(['Female'])]
female_white = female.loc[female.merged_race_ethnicity_v2.isin(['White'])]
female_white = female_white.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp=sns.heatmap(female_white, annot=False,cmap="PuBu_r", yticklabels=False)
plt.savefig('../figures/female_white_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
male_latino = male.loc[male.merged_race_ethnicity_v2.isin(['Hispanic or Latino'])]
male_latino = male_latino.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp=sns.heatmap(male_latino, annot=False,cmap="PuBu_r", yticklabels=False)
plt.savefig('../figures/male_latino_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
female = CCSR.loc[CCSR.merged_gender.isin(['Female'])]
female_latina = female.loc[female.merged_race_ethnicity_v2.isin(['Hispanic or Latino'])]
female_latina = female_latina.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp=sns.heatmap(female_latina, annot=False,cmap="PuBu_r", yticklabels=False)
plt.savefig('../figures/female_latina_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
male_asian = male.loc[male.merged_race_ethnicity_v2.isin(['Asian'])]
male_asian = male_asian.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp=sns.heatmap(male_asian, annot=False,cmap="PuBu_r", yticklabels=False)
plt.savefig('../figures/male_asian_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
female = CCSR.loc[CCSR.merged_gender.isin(['Female'])]
female_asian = female.loc[female.merged_race_ethnicity_v2.isin(['Asian'])]
female_asian = female_asian.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp=sns.heatmap(female_asian, annot=False,cmap="PuBu_r", yticklabels=False)
plt.savefig('../figures/female_asian_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
straight = CCSR.loc[CCSR.xtn_sexual_orientation_source_concept_name.isin(['Straight (not lesbian or gay)'])]
straight = straight.loc[straight.merged_gender.isin(['Female', 'Male'])]
straight = straight.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp = sns.heatmap(straight, annot=False,cmap="Blues_r", yticklabels=False)
plt.savefig('../figures/straight_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
queer = CCSR.loc[CCSR.merged_gender.isin(['Non-binary', 'Transgender Female', 'Transgender Male', 'Gender Non-conforming', 'Gender Queer', 'Other', 'Uncertain']) | CCSR.xtn_sexual_orientation_source_concept_name.isin(['Lesbian or Gay', 'Bisexual', 'Queer', 'Something else', 'Don\'t know'])]
queer = queer.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp = sns.heatmap(queer, annot=False,cmap="Blues_r", yticklabels=False)
plt.savefig('../figures/queer_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
queer_black = CCSR.loc[CCSR.merged_race_ethnicity_v2.isin(['Black or African American'])]
queer_black = queer_black.loc[queer_black.merged_gender.isin(['Non-binary', 'Transgender Female', 'Transgender Male', 'Gender Non-conforming', 'Gender Queer', 'Other', 'Uncertain']) | queer_black.xtn_sexual_orientation_source_concept_name.isin(['Lesbian or Gay', 'Bisexual', 'Queer', 'Something else', 'Don\'t know'])]
queer_black = queer_black.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp = sns.heatmap(queer_black, annot=False,cmap="Blues_r", yticklabels=False)
plt.savefig('../figures/queer_black_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
queer_white = CCSR.loc[CCSR.merged_race_ethnicity_v2.isin(['White'])]
queer_white = queer_white.loc[queer_white.merged_gender.isin(['Non-binary', 'Transgender Female', 'Transgender Male', 'Gender Non-conforming', 'Gender Queer', 'Other', 'Uncertain']) | queer_white.xtn_sexual_orientation_source_concept_name.isin(['Lesbian or Gay', 'Bisexual', 'Queer', 'Something else', 'Don\'t know'])]
queer_white = queer_white.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp = sns.heatmap(queer_white, annot=False,cmap="Blues_r", yticklabels=False)
plt.savefig('../figures/queer_white_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
queer_latinx = CCSR.loc[CCSR.merged_race_ethnicity_v2.isin(['Hispanic or Latino'])]
queer_latinx = queer_latinx.loc[queer_latinx.merged_gender.isin(['Non-binary', 'Transgender Female', 'Transgender Male', 'Gender Non-conforming', 'Gender Queer', 'Other', 'Uncertain']) | queer_latinx.xtn_sexual_orientation_source_concept_name.isin(['Lesbian or Gay', 'Bisexual', 'Queer', 'Something else', 'Don\'t know'])]
queer_latinx = queer_latinx.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp = sns.heatmap(queer_latinx, annot=False,cmap="Blues_r", yticklabels=False)
plt.savefig('../figures/queer_latinx_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
queer_asian = CCSR.loc[CCSR.merged_race_ethnicity_v2.isin(['Asian'])]
queer_asian = queer_asian.loc[queer_asian.merged_gender.isin(['Non-binary', 'Transgender Female', 'Transgender Male', 'Gender Non-conforming', 'Gender Queer', 'Other', 'Uncertain']) | queer_asian.xtn_sexual_orientation_source_concept_name.isin(['Lesbian or Gay', 'Bisexual', 'Queer', 'Something else', 'Don\'t know'])]
queer_asian = queer_asian.loc[:,'Alcohol-related disorders':'Trauma- and stressor-related disorders']
pp = sns.heatmap(queer_asian, annot=False,cmap="Blues_r", yticklabels=False)
plt.savefig('../figures/queer_asian_all_encounters.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
straight = condition_ratios_broadICD.loc[condition_ratios_broadICD.xtn_sexual_orientation_source_concept_name.isin([
    'Straight (not lesbian or gay)'])]
straight = straight.loc[straight.merged_gender.isin(['Female', 'Male'])]
straight = straight.loc[:,'F30':'F68']
pp=sns.heatmap(straight, annot=False,cmap="cubehelix", yticklabels=False)
pp.axes.set_xticklabels(['Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders',
                         'Somatoform disorders',
                         'Other nonpsychotic mental disorders',
                         'Eating disorders',
                         'Sleep disorders not due to substance/known condition',
                         'Sexual dysfunction not due to a substance/known condition',
                         'Mental and behavioral disorders associated with the puerperium',
                         'Psychological/behavioral factors associated with disorders/diseases classified elsewhere',
                         'Unspecified behavioral syndromes associated with physiological/physical factors',
                         'Specific personality disorders',
                         'Impulse disorders',
                         'Gender identity disorders',
                         'Paraphilias',
                         'Other disorders of adult personality and behavior'], rotation=90)
plt.savefig('straight_cisgender.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
queer_gender = condition_ratios_broadICD.loc[condition_ratios_broadICD.merged_gender.isin(['Non-binary', 'Transgender Female', 'Transgender Male', 'Gender Non-conforming', 'Gender Queer', 'Other', 'Uncertain'])]
queer_gender = queer_gender.loc[:,'F30':'F68']
pp=sns.heatmap(queer_gender, annot=False,cmap="cubehelix", yticklabels=False)
pp.axes.set_xticklabels(['Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders',
                         'Somatoform disorders',
                         'Other nonpsychotic mental disorders',
                         'Eating disorders',
                         'Sleep disorders not due to substance/known condition',
                         'Sexual dysfunction not due to a substance/known condition',
                         'Mental and behavioral disorders associated with the puerperium',
                         'Psychological/behavioral factors associated with disorders/diseases classified elsewhere',
                         'Unspecified behavioral syndromes associated with physiological/physical factors',
                         'Specific personality disorders',
                         'Impulse disorders',
                         'Gender identity disorders',
                         'Paraphilias',
                         'Other disorders of adult personality and behavior'], rotation=90)
plt.savefig('queer_gender.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
queer_sexuality = condition_ratios_broadICD.loc[condition_ratios_broadICD.xtn_sexual_orientation_source_concept_name.isin(['Lesbian or Gay', 'Bisexual', 'Queer', 'Something else', 'Don\'t know'])]
queer_sexuality = queer_sexuality.loc[:,'F30':'F68']
pp = sns.heatmap(queer_sexuality, annot=False,cmap="cubehelix", yticklabels=False)
pp.axes.set_xticklabels(['Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders',
                         'Somatoform disorders',
                         'Other nonpsychotic mental disorders',
                         'Eating disorders',
                         'Sleep disorders not due to substance/known condition',
                         'Sexual dysfunction not due to a substance/known condition',
                         'Mental and behavioral disorders associated with the puerperium',
                         'Psychological/behavioral factors associated with disorders/diseases classified elsewhere',
                         'Unspecified behavioral syndromes associated with physiological/physical factors',
                         'Specific personality disorders',
                         'Impulse disorders',
                         'Gender identity disorders',
                         'Paraphilias',
                         'Other disorders of adult personality and behavior'], rotation=90)
plt.savefig('queer_sexuality.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
female = condition_ratios_broadICD[condition_ratios_broadICD.merged_gender == 'Female']
female_black = female.loc[female.merged_race_ethnicity_v2.isin(['White','Asian','Black or African American', 'Hispanic or Latino'])]
female_black = female_black.sort_values(by=['merged_race_ethnicity_v2'])
female_black = female_black.loc[:,'F01':'F99']
sns.heatmap(female_black, annot=False,cmap="Reds", yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
female_black = female.loc[female.merged_race_ethnicity_v2.isin(['Black or African American'])]
female_black = female_black.sort_values(by=['merged_race_ethnicity_v2'])
female_black = female_black.loc[:,'F20':'F44']
pp = sns.heatmap(female_black, annot=False,cmap="Reds_r", yticklabels=False)
pp.axes.set_xticklabels(['Schizophrenia',
                         'Schizotypal disorder',
                         'Delusional disorders',
                         'Brief psychotic disorder',
                         'Shared psychotic disorder',
                         'Schizoaffective disorders',
                         'Unspecified psychosis, no substance or known condition',
                         'Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders'], rotation=90)
plt.savefig('female_black_schizophrenia.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
female_white = female.loc[female.merged_race_ethnicity_v2.isin(['White'])]
female_white = female_white.sort_values(by=['merged_race_ethnicity_v2'])
female_white = female_white.loc[:,'F20':'F44']
pp = sns.heatmap(female_white, annot=False,cmap="Reds_r", yticklabels=False)
pp.axes.set_xticklabels(['Schizophrenia',
                         'Schizotypal disorder',
                         'Delusional disorders',
                         'Brief psychotic disorder',
                         'Shared psychotic disorder',
                         'Schizoaffective disorders',
                         'Unspecified psychosis, no substance or known condition',
                         'Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders'], rotation=90)
plt.savefig('female_white_schizophrenia.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
female_asian = female.loc[female.merged_race_ethnicity_v2.isin(['Asian'])]
female_asian = female_asian.sort_values(by=['merged_race_ethnicity_v2'])
female_asian = female_asian.loc[:,'F20':'F44']
pp = sns.heatmap(female_asian, annot=False,cmap="Reds_r", yticklabels=False)
pp.axes.set_xticklabels(['Schizophrenia',
                         'Schizotypal disorder',
                         'Delusional disorders',
                         'Brief psychotic disorder',
                         'Shared psychotic disorder',
                         'Schizoaffective disorders',
                         'Unspecified psychosis, no substance or known condition',
                         'Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders'], rotation=90)
plt.savefig('female_asian_schizophrenia.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
female_latina = female.loc[female.merged_race_ethnicity_v2.isin(['Hispanic or Latino'])]
female_latina = female_latina.sort_values(by=['merged_race_ethnicity_v2'])
female_latina = female_latina.loc[:,'F20':'F44']
pp = sns.heatmap(female_latina, annot=False,cmap="Reds_r", yticklabels=False)
pp.axes.set_xticklabels(['Schizophrenia',
                         'Schizotypal disorder',
                         'Delusional disorders',
                         'Brief psychotic disorder',
                         'Shared psychotic disorder',
                         'Schizoaffective disorders',
                         'Unspecified psychosis, no substance or known condition',
                         'Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders'], rotation=90)
plt.savefig('female_latina_schizophrenia.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
male = condition_ratios_broadICD[condition_ratios_broadICD.merged_gender == 'Male']
male_black = male.loc[male.merged_race_ethnicity_v2.isin(['Black or African American'])]
male_black = male_black.sort_values(by=['merged_race_ethnicity_v2'])
male_black = male_black.loc[:,'F20':'F44']
pp = sns.heatmap(male_black,annot=False,cmap="Blues_r", yticklabels=False)
pp.axes.set_xticklabels(['Schizophrenia',
                         'Schizotypal disorder',
                         'Delusional disorders',
                         'Brief psychotic disorder',
                         'Shared psychotic disorder',
                         'Schizoaffective disorders',
                         'Unspecified psychosis, no substance or known condition',
                         'Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders'], rotation=90)
plt.savefig('male_black_schizophrenia.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
male_white = male.loc[male.merged_race_ethnicity_v2.isin(['White'])]
male_white = male_white.sort_values(by=['merged_race_ethnicity_v2'])
male_white = male_white.loc[:,'F20':'F44']
pp = sns.heatmap(male_white,annot=False, cmap="Blues_r", yticklabels=False)
pp.axes.set_xticklabels(['Schizophrenia',
                         'Schizotypal disorder',
                         'Delusional disorders',
                         'Brief psychotic disorder',
                         'Shared psychotic disorder',
                         'Schizoaffective disorders',
                         'Unspecified psychosis, no substance or known condition',
                         'Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders'], rotation=90)
plt.savefig('male_white_schizophrenia.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
male_latino = male.loc[male.merged_race_ethnicity_v2.isin(['Hispanic or Latino'])]
male_latino = male_latino.sort_values(by=['merged_race_ethnicity_v2'])
male_latino = male_latino.loc[:,'F20':'F44']
pp = sns.heatmap(male_latino,annot=False, cmap="Blues_r", yticklabels=False)
pp.axes.set_xticklabels(['Schizophrenia',
                         'Schizotypal disorder',
                         'Delusional disorders',
                         'Brief psychotic disorder',
                         'Shared psychotic disorder',
                         'Schizoaffective disorders',
                         'Unspecified psychosis, no substance or known condition',
                         'Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders'], rotation=90)
plt.savefig('male_latino_schizophrenia.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
male_other = male.loc[male.merged_race_ethnicity_v2.isin(['Other Race'])]
male_other = male_other.sort_values(by=['merged_race_ethnicity_v2'])
male_other = male_other.loc[:,'F20':'F44']
pp = sns.heatmap(male_other,annot=False, cmap="Blues_r", yticklabels=False)
pp.axes.set_xticklabels(['Schizophrenia',
                         'Schizotypal disorder',
                         'Delusional disorders',
                         'Brief psychotic disorder',
                         'Shared psychotic disorder',
                         'Schizoaffective disorders',
                         'Unspecified psychosis, no substance or known condition',
                         'Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders'], rotation=90)
plt.savefig('male_other_schizophrenia.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
male_asian = male.loc[male.merged_race_ethnicity_v2.isin(['Asian'])]
male_asian = male_asian.sort_values(by=['merged_race_ethnicity_v2'])
male_asian = male_asian.loc[:,'F20':'F44']
pp = sns.heatmap(male_asian,annot=False, cmap="Blues_r", yticklabels=False)
pp.axes.set_xticklabels(['Schizophrenia',
                         'Schizotypal disorder',
                         'Delusional disorders',
                         'Brief psychotic disorder',
                         'Shared psychotic disorder',
                         'Schizoaffective disorders',
                         'Unspecified psychosis, no substance or known condition',
                         'Manic episode',
                         'Bipolar disorder',
                         'Depressive episode',
                         'Major depressive disorder, recurrent',
                         'Persistent mood [affective] disorders',
                         'Unspecified mood [affective] disorder',
                         'Phobic anxiety disorders',
                         'Other anxiety disorders',
                         'Obsessive-compulsive disorder',
                         'Reaction to severe stress, and adjustment disorders',
                         'Dissociative and conversion disorders'], rotation=90)
plt.savefig('male_asian_schizophrenia.png', transparent=False, format='png', dpi=300, bbox_inches='tight')

# %%
male = male.loc[male.merged_race_ethnicity_v2.isin(['White', 'Black or African American', 'Hispanic/Latino', 'Asian'])]
male = male.sort_values(by=['merged_race_ethnicity_v2'])
male = male.loc[:,'F01':'F99']
sns.heatmap(male,annot=False, cmap="Blues", yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
g = psych_encounters.groupby(['ICD_top_h','billing_condition','insured_status_x'])
condition_cnt = g.visit_occurrence_id.nunique()
uninsured = condition_cnt.loc[:,:,'Uninsured'].reset_index().pivot(index='ICD_top_h', columns='billing_condition', values='visit_occurrence_id')
uninsured.fillna(0, inplace=True)
# Uninsured = Uninsured.reindex(range(0,8469), axis=0, fill_value=0)

insured = condition_cnt.loc[:,:,'Insured'].reset_index().pivot(index='ICD_top_h', columns='billing_condition', values='visit_occurrence_id')
insured.fillna(0, inplace=True)
# insured = insured.reindex(range(0,8469), axis=0, fill_value=0)
sns.heatmap(uninsured, cmap="mako")
plt.title("Self-Pay Patients")
plt.show()
# plt.savefig('SelfPay.png', transparent=False, format='png', dpi=300, bbox_inches='tight')
sns.heatmap(insured, cmap="mako")
plt.title("Insured Patients")
plt.show()
# plt.savefig('Insured.png', transparent=False, format='png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 g = psych_encounters.groupby(['ICD_top_h','billing_condition','insured_status_x'])
#       2 condition_cnt = g.visit_occurrence_id.nunique()
#       3 uninsured = condition_cnt.loc[:,:,'Uninsured'].reset_index().pivot(index='ICD_top_h', columns='billing_condition', values='visit_occurrence_id')
#
# File ~/psych_nlp/psych_note_venv/lib/python3.8/site-packages/pandas/core/frame.py:7721, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7716 axis = self._get_axis_number(axis)
#    7718 # https://github.com/python/mypy/issues/7642
#    7719 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720 # "Union[bool, NoDefault]"; expected "bool"
# -> 7721 return DataFrameGroupBy(
#    7722     obj=self,
#    7723     keys=by,
# ...
